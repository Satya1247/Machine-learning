# %% [markdown]
# #pandas

# %%
#pandas is panel data
#used for data manipulation and analyzation

# %%
#numpy is work for 50k row or col..it can only integer datatype
#pandas it performs better than 500k 
#it can use any data type

# %% [markdown]
# #pandas has series(1d)
# #pandas has dataframe(2d)
# panel(3d)

# %%
'''1d series
collection of series is 2d
collection of 2d is 3d'''
# Out:
# '1d series\ncollection of series is 2d\ncollection of 2d is 3d'

# %%
import pandas as pd

# %%
#1d data of pandas or series
a=[1,2,3,4,5]
s=pd.Series(a)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s[4]
# Out:
# 5

# %%
s1=pd.Series([11,12,13,14,15],index=["a","b","c","d","e"])
s1
# Out:
# a    11
# b    12
# c    13
# d    14
# e    15
# dtype: int64

# %%
s1["b"]
# Out:
# 12

# %% [markdown]
# #creating series in different ways

# %%
import numpy as np

# %%
x=pd.Series(np.random.randint(2,67,size=6),index=[11,12,13,14,15,16])

# %%
x
# Out:
# 11    27
# 12    19
# 13     4
# 14    64
# 15    32
# 16    10
# dtype: int32

# %% [markdown]
# # x1=pd.Series((1,2,3,4,5))

# %%
x1=pd.Series((1,2,3,4,5))

# %%
x1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
x2=pd.Series({
    1:1,2:2
})

# %%
x2
# Out:
# 1    1
# 2    2
# dtype: int64

# %% [markdown]
# 2d data pandas dataframe

# %%
name=["aaa","bbb","ccc","ddd","eee"]

# %%
df=pd.DataFrame({"name":["aaa","bbb","ccc","ddd","eee","fff","ggg","hhh"]
                "age":[11,12,13,14,15,16,17,18],"sub":["s1","s2","s3","s4","s5","s6","s7","s8"]})
# Out:
#   File "C:\Users\DELL\AppData\Local\Temp/ipykernel_6536/658001713.py", line 2
#     "age":[11,12,13,14,15,16,17,18],"sub":["s1","s2","s3","s4","s5","s6","s7","s8"]})
#     ^
# SyntaxError: invalid syntax

# %%
s=[("abc",12),("bcd",45),("asd",49)]

# %%
df=pd.DataFrame(s,columns=["name","age"])

# %%
df
# Out:
#   name  age
# 0  abc   12
# 1  bcd   45
# 2  asd   49

# %%
df.describe()
# Out:
#              age
# count   3.000000
# mean   35.333333
# std    20.305993
# min    12.000000
# 25%    28.500000
# 50%    45.000000
# 75%    47.000000
# max    49.000000

# %%
df["age"].mean()
# Out:
# 35.333333333333336

# %%
df["age"].std()
# Out:
# 20.305992547357377

# %%
df = pd.read_csv("C:/Users/DELL/Downloads/car_sales.csv")

# %%
df
# Out:
#     Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0            1        Acura  Integra    Small       12.9   15.9       18.8
# 1            2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2            3         Audi       90  Compact       25.9   29.1       32.3
# 3            4         Audi      100  Midsize       30.8   37.7       44.6
# 4            5          BMW     535i  Midsize       23.7   30.0       36.2
# ..         ...          ...      ...      ...        ...    ...        ...
# 88          89   Volkswagen  Eurovan      Van       16.6   19.7       22.7
# 89          90   Volkswagen   Passat  Compact       17.6   20.0       22.4
# 90          91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7
# 91          92        Volvo      240  Compact       21.8   22.7       23.5
# 92          93        Volvo      850  Midsize       24.8   26.7       28.5
#
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0           1        Acura  Integra    Small       12.9   15.9       18.8
# 1           2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2           3         Audi       90  Compact       25.9   29.1       32.3
# 3           4         Audi      100  Midsize       30.8   37.7       44.6
# 4           5          BMW     535i  Midsize       23.7   30.0       36.2
#
#    MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# 0        25           31                None  ...          5    177
# 1        18           25  Driver & Passenger  ...          5    195
# 2        20           26         Driver only  ...          5    180
# 3        19           26  Driver & Passenger  ...          6    193
# 4        22           30         Driver only  ...          4    186
#
#    Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# ...

# %%
df.tail(5)
# Out:
#     Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 88          89   Volkswagen  Eurovan      Van       16.6   19.7       22.7
# 89          90   Volkswagen   Passat  Compact       17.6   20.0       22.4
# 90          91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7
# 91          92        Volvo      240  Compact       21.8   22.7       23.5
# 92          93        Volvo      850  Midsize       24.8   26.7       28.5
#
#     MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# 88        17           21                None  ...          7    187
# 89        21           30                None  ...          5    180
# 90        18           25                None  ...          4    159
# 91        21           28         Driver only  ...          5    190
# 92        20           28  Driver & Passenger  ...          5    184
#
#     Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0  Min.Price      Price  Max.Price   MPG.city  MPG.highway  \
# count   93.000000  93.000000  93.000000  93.000000  93.000000    93.000000
# mean    47.000000  17.125806  19.509677  21.898925  22.365591    29.086022
# std     26.990739   8.746029   9.659430  11.030457   5.619812     5.331726
# min      1.000000   6.700000   7.400000   7.900000  15.000000    20.000000
# 25%     24.000000  10.800000  12.200000  14.700000  18.000000    26.000000
# 50%     47.000000  14.700000  17.700000  19.600000  21.000000    28.000000
# 75%     70.000000  20.300000  23.300000  25.300000  25.000000    31.000000
# max     93.000000  45.400000  61.900000  80.000000  46.000000    50.000000
#
#        EngineSize  Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  \
# count   93.000000   93.000000    93.000000     93.000000           93.000000
# mean     2.667742  143.827957  5280.645161   2332.204301           16.664516
# ...

# %%
df[["Manufacturer","Model"]]
# Out:
#    Manufacturer    Model
# 0         Acura  Integra
# 1         Acura   Legend
# 2          Audi       90
# 3          Audi      100
# 4           BMW     535i
# ..          ...      ...
# 88   Volkswagen  Eurovan
# 89   Volkswagen   Passat
# 90   Volkswagen  Corrado
# 91        Volvo      240
# 92        Volvo      850
#
# [93 rows x 2 columns]

# %%
df[df["Manufacturer"]=="Volvo"].count()
# Out:
# Unnamed: 0            2
# Manufacturer          2
# Model                 2
# Type                  2
# Min.Price             2
# Price                 2
# Max.Price             2
# MPG.city              2
# MPG.highway           2
# AirBags               2
# DriveTrain            2
# Cylinders             2
# EngineSize            2
# Horsepower            2
# RPM                   2
# Rev.per.mile          2
# Man.trans.avail       2
# Fuel.tank.capacity    2
# Passengers            2
# Length                2
# Wheelbase             2
# Width                 2
# Turn.circle           2
# Rear.seat.room        2
# Luggage.room          2
# Weight                2
# Origin                2
# Make                  2
# dtype: int64

# %% [markdown]
# df[df["Gender"]=="female" & df["Weight"]>100].count()
